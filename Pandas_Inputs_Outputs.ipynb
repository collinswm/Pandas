# %% [markdown]
# Pandas Input and Output methods
# ---

# %%
import pandas as pd

# %% [markdown]
# Examples of Pandas data reading capabilities

# %%
# !pwd
# Out:
# /Users/billy/Desktop/DS_Master/Udemy/PyTorch_for_Deep_Learning/PYTORCH_NOTEBOOKS/07-My_Notebooks

# %%
#Reading a CSV File
df_example = pd.read_csv('~/Desktop/DS_Master/Udemy/PyTorch_for_Deep_Learning/PYTORCH_NOTEBOOKS/00-Crash-Course-Topics/01-Crash-Course-Pandas/example.csv', sep = ",")
df_example
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
#Reading a CSV File

df_bank = pd.read_csv('~/Desktop/DS_Master/Udemy/PyTorch_for_Deep_Learning/PYTORCH_NOTEBOOKS/00-Crash-Course-Topics/01-Crash-Course-Pandas/bank.csv', sep=',')
df_bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
#Reading a HTML File

df_html = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
df = df_html[0]
df
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
type(df_html)
# Out:
# list

# %%
len(df_html) # It only found a single table.
# Out:
# 1
